# %%
#Reading data
import pandas as pd


#Fixings warnings
import warnings 
warnings.filterwarnings('ignore')


#For mathematical operations
import numpy as np


#Visualisation
import seaborn as sns 
import plotly.express as px
from termcolor import colored
import matplotlib.pyplot as plt 
import plotly.graph_objects as go
import plotly.figure_factory as ff


#Data spliting
from sklearn.model_selection import train_test_split

# %%
sleep_data=pd.read_csv("C:/Users/vikas/Downloads/archive/Sleep_health_and_lifestyle_dataset.csv")

#head() for display the first 5 rows  
sleep_data.head().style.set_properties(**{'background-color': '#4A235A',
                                          'color': '#E2EEF3'}) #for colored output
# Out:
# <style type="text/css">
# #T_25111_row0_col0, #T_25111_row0_col1, #T_25111_row0_col2, #T_25111_row0_col3, #T_25111_row0_col4, #T_25111_row0_col5, #T_25111_row0_col6, #T_25111_row0_col7, #T_25111_row0_col8, #T_25111_row0_col9, #T_25111_row0_col10, #T_25111_row0_col11, #T_25111_row0_col12, #T_25111_row1_col0, #T_25111_row1_col1, #T_25111_row1_col2, #T_25111_row1_col3, #T_25111_row1_col4, #T_25111_row1_col5, #T_25111_row1_col6, #T_25111_row1_col7, #T_25111_row1_col8, #T_25111_row1_col9, #T_25111_row1_col10, #T_25111_row1_col11, #T_25111_row1_col12, #T_25111_row2_col0, #T_25111_row2_col1, #T_25111_row2_col2, #T_25111_row2_col3, #T_25111_row2_col4, #T_25111_row2_col5, #T_25111_row2_col6, #T_25111_row2_col7, #T_25111_row2_col8, #T_25111_row2_col9, #T_25111_row2_col10, #T_25111_row2_col11, #T_25111_row2_col12, #T_25111_row3_col0, #T_25111_row3_col1, #T_25111_row3_col2, #T_25111_row3_col3, #T_25111_row3_col4, #T_25111_row3_col5, #T_25111_row3_col6, #T_25111_row3_col7, #T_25111_row3_col8, #T_25111_row3_col9, #T_25111_row3_col10, #T_25111_row3_col11, #T_25111_row3_col12, #T_25111_row4_col0, #T_25111_row4_col1, #T_25111_row4_col2, #T_25111_row4_col3, #T_25111_row4_col4, #T_25111_row4_col5, #T_25111_row4_col6, #T_25111_row4_col7, #T_25111_row4_col8, #T_25111_row4_col9, #T_25111_row4_col10, #T_25111_row4_col11, #T_25111_row4_col12 {
#   background-color: #4A235A;
#   color: #E2EEF3;
# }
# </style>
# <table id="T_25111">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_25111_level0_col0" class="col_heading level0 col0" >Person ID</th>
#       <th id="T_25111_level0_col1" class="col_heading level0 col1" >Gender</th>
#       <th id="T_25111_level0_col2" class="col_heading level0 col2" >Age</th>
#       <th id="T_25111_level0_col3" class="col_heading level0 col3" >Occupation</th>
#       <th id="T_25111_level0_col4" class="col_heading level0 col4" >Sleep Duration</th>
#       <th id="T_25111_level0_col5" class="col_heading level0 col5" >Quality of Sleep</th>
#       <th id="T_25111_level0_col6" class="col_heading level0 col6" >Physical Activity Level</th>
#       <th id="T_25111_level0_col7" class="col_heading level0 col7" >Stress Level</th>
#       <th id="T_25111_level0_col8" class="col_heading level0 col8" >BMI Category</th>
#       <th id="T_25111_level0_col9" class="col_heading level0 col9" >Blood Pressure</th>
#       <th id="T_25111_level0_col10" class="col_heading level0 col10" >Heart Rate</th>
#       <th id="T_25111_level0_col11" class="col_heading level0 col11" >Daily Steps</th>
#       <th id="T_25111_level0_col12" class="col_heading level0 col12" >Sleep Disorder</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25111_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_25111_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_25111_row0_col1" class="data row0 col1" >Male</td>
#       <td id="T_25111_row0_col2" class="data row0 col2" >27</td>
#       <td id="T_25111_row0_col3" class="data row0 col3" >Software Engineer</td>
#       <td id="T_25111_row0_col4" class="data row0 col4" >6.100000</td>
#       <td id="T_25111_row0_col5" class="data row0 col5" >6</td>
#       <td id="T_25111_row0_col6" class="data row0 col6" >42</td>
#       <td id="T_25111_row0_col7" class="data row0 col7" >6</td>
#       <td id="T_25111_row0_col8" class="data row0 col8" >Overweight</td>
#       <td id="T_25111_row0_col9" class="data row0 col9" >126/83</td>
#       <td id="T_25111_row0_col10" class="data row0 col10" >77</td>
#       <td id="T_25111_row0_col11" class="data row0 col11" >4200</td>
#       <td id="T_25111_row0_col12" class="data row0 col12" >None</td>
#     </tr>
#     <tr>
#       <th id="T_25111_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_25111_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_25111_row1_col1" class="data row1 col1" >Male</td>
#       <td id="T_25111_row1_col2" class="data row1 col2" >28</td>
#       <td id="T_25111_row1_col3" class="data row1 col3" >Doctor</td>
#       <td id="T_25111_row1_col4" class="data row1 col4" >6.200000</td>
#       <td id="T_25111_row1_col5" class="data row1 col5" >6</td>
#       <td id="T_25111_row1_col6" class="data row1 col6" >60</td>
#       <td id="T_25111_row1_col7" class="data row1 col7" >8</td>
#       <td id="T_25111_row1_col8" class="data row1 col8" >Normal</td>
#       <td id="T_25111_row1_col9" class="data row1 col9" >125/80</td>
#       <td id="T_25111_row1_col10" class="data row1 col10" >75</td>
#       <td id="T_25111_row1_col11" class="data row1 col11" >10000</td>
#       <td id="T_25111_row1_col12" class="data row1 col12" >None</td>
#     </tr>
#     <tr>
#       <th id="T_25111_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_25111_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_25111_row2_col1" class="data row2 col1" >Male</td>
#       <td id="T_25111_row2_col2" class="data row2 col2" >28</td>
#       <td id="T_25111_row2_col3" class="data row2 col3" >Doctor</td>
#       <td id="T_25111_row2_col4" class="data row2 col4" >6.200000</td>
#       <td id="T_25111_row2_col5" class="data row2 col5" >6</td>
#       <td id="T_25111_row2_col6" class="data row2 col6" >60</td>
#       <td id="T_25111_row2_col7" class="data row2 col7" >8</td>
#       <td id="T_25111_row2_col8" class="data row2 col8" >Normal</td>
#       <td id="T_25111_row2_col9" class="data row2 col9" >125/80</td>
#       <td id="T_25111_row2_col10" class="data row2 col10" >75</td>
#       <td id="T_25111_row2_col11" class="data row2 col11" >10000</td>
#       <td id="T_25111_row2_col12" class="data row2 col12" >None</td>
#     </tr>
#     <tr>
#       <th id="T_25111_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_25111_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_25111_row3_col1" class="data row3 col1" >Male</td>
#       <td id="T_25111_row3_col2" class="data row3 col2" >28</td>
#       <td id="T_25111_row3_col3" class="data row3 col3" >Sales Representative</td>
#       <td id="T_25111_row3_col4" class="data row3 col4" >5.900000</td>
#       <td id="T_25111_row3_col5" class="data row3 col5" >4</td>
#       <td id="T_25111_row3_col6" class="data row3 col6" >30</td>
#       <td id="T_25111_row3_col7" class="data row3 col7" >8</td>
#       <td id="T_25111_row3_col8" class="data row3 col8" >Obese</td>
#       <td id="T_25111_row3_col9" class="data row3 col9" >140/90</td>
#       <td id="T_25111_row3_col10" class="data row3 col10" >85</td>
#       <td id="T_25111_row3_col11" class="data row3 col11" >3000</td>
#       <td id="T_25111_row3_col12" class="data row3 col12" >Sleep Apnea</td>
#     </tr>
#     <tr>
#       <th id="T_25111_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_25111_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_25111_row4_col1" class="data row4 col1" >Male</td>
#       <td id="T_25111_row4_col2" class="data row4 col2" >28</td>
#       <td id="T_25111_row4_col3" class="data row4 col3" >Sales Representative</td>
#       <td id="T_25111_row4_col4" class="data row4 col4" >5.900000</td>
#       <td id="T_25111_row4_col5" class="data row4 col5" >4</td>
#       <td id="T_25111_row4_col6" class="data row4 col6" >30</td>
#       <td id="T_25111_row4_col7" class="data row4 col7" >8</td>
#       <td id="T_25111_row4_col8" class="data row4 col8" >Obese</td>
#       <td id="T_25111_row4_col9" class="data row4 col9" >140/90</td>
#       <td id="T_25111_row4_col10" class="data row4 col10" >85</td>
#       <td id="T_25111_row4_col11" class="data row4 col11" >3000</td>
#       <td id="T_25111_row4_col12" class="data row4 col12" >Sleep Apnea</td>
#     </tr>
#   </tbody>
# </table>

# %%
  shape = colored(sleep_data.shape, "magenta",None, attrs=["blink"])
print('The dimention of data is :',shape)
# Out:
# The dimention of data is : (374, 13)

# %%
sleep_data.info() # for empty and type of values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           374 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
#for statistical info
sleep_data.describe().style.background_gradient(cmap='BuPu') #for colored output
# Out:
# <style type="text/css">
# #T_fe7e7_row0_col0, #T_fe7e7_row0_col1, #T_fe7e7_row0_col2, #T_fe7e7_row0_col3, #T_fe7e7_row0_col4, #T_fe7e7_row0_col5, #T_fe7e7_row0_col6, #T_fe7e7_row7_col0, #T_fe7e7_row7_col7 {
#   background-color: #4d004b;
#   color: #f1f1f1;
# }
# #T_fe7e7_row0_col7, #T_fe7e7_row2_col1, #T_fe7e7_row2_col2, #T_fe7e7_row2_col3, #T_fe7e7_row2_col4, #T_fe7e7_row2_col5, #T_fe7e7_row2_col6, #T_fe7e7_row3_col0, #T_fe7e7_row3_col5 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_fe7e7_row1_col0, #T_fe7e7_row5_col0 {
#   background-color: #8c95c6;
#   color: #f1f1f1;
# }
# #T_fe7e7_row1_col1 {
#   background-color: #e6f0f7;
#   color: #000000;
# }
# #T_fe7e7_row1_col2, #T_fe7e7_row1_col3, #T_fe7e7_row5_col2, #T_fe7e7_row6_col2, #T_fe7e7_row6_col3, #T_fe7e7_row7_col5 {
#   background-color: #f4fafc;
#   color: #000000;
# }
# #T_fe7e7_row1_col4 {
#   background-color: #e4eef5;
#   color: #000000;
# }
# #T_fe7e7_row1_col5, #T_fe7e7_row5_col5 {
#   background-color: #f6fbfc;
#   color: #000000;
# }
# #T_fe7e7_row1_col6, #T_fe7e7_row5_col6 {
#   background-color: #d2e2ee;
#   color: #000000;
# }
# #T_fe7e7_row1_col7 {
#   background-color: #8b5caa;
#   color: #f1f1f1;
# }
# #T_fe7e7_row2_col0 {
#   background-color: #b5cce3;
#   color: #000000;
# }
# #T_fe7e7_row2_col7 {
#   background-color: #dfebf4;
#   color: #000000;
# }
# #T_fe7e7_row3_col1 {
#   background-color: #eef6fa;
#   color: #000000;
# }
# #T_fe7e7_row3_col2, #T_fe7e7_row4_col2, #T_fe7e7_row4_col3, #T_fe7e7_row5_col3, #T_fe7e7_row6_col5 {
#   background-color: #f5fafc;
#   color: #000000;
# }
# #T_fe7e7_row3_col3, #T_fe7e7_row4_col5 {
#   background-color: #f6fbfd;
#   color: #000000;
# }
# #T_fe7e7_row3_col4 {
#   background-color: #f3f9fb;
#   color: #000000;
# }
# #T_fe7e7_row3_col6 {
#   background-color: #d6e4f0;
#   color: #000000;
# }
# #T_fe7e7_row3_col7 {
#   background-color: #bacfe4;
#   color: #000000;
# }
# #T_fe7e7_row4_col0 {
#   background-color: #bfd3e6;
#   color: #000000;
# }
# #T_fe7e7_row4_col1 {
#   background-color: #eaf3f8;
#   color: #000000;
# }
# #T_fe7e7_row4_col4 {
#   background-color: #ebf3f8;
#   color: #000000;
# }
# #T_fe7e7_row4_col6 {
#   background-color: #d3e2ef;
#   color: #000000;
# }
# #T_fe7e7_row4_col7 {
#   background-color: #8c88bf;
#   color: #f1f1f1;
# }
# #T_fe7e7_row5_col1 {
#   background-color: #e6f0f6;
#   color: #000000;
# }
# #T_fe7e7_row5_col4, #T_fe7e7_row6_col1 {
#   background-color: #e3eef5;
#   color: #000000;
# }
# #T_fe7e7_row5_col7 {
#   background-color: #8a55a7;
#   color: #f1f1f1;
# }
# #T_fe7e7_row6_col0 {
#   background-color: #88409c;
#   color: #f1f1f1;
# }
# #T_fe7e7_row6_col4 {
#   background-color: #d9e6f1;
#   color: #000000;
# }
# #T_fe7e7_row6_col6 {
#   background-color: #d1e1ee;
#   color: #000000;
# }
# #T_fe7e7_row6_col7 {
#   background-color: #863092;
#   color: #f1f1f1;
# }
# #T_fe7e7_row7_col1 {
#   background-color: #ddeaf3;
#   color: #000000;
# }
# #T_fe7e7_row7_col2, #T_fe7e7_row7_col3 {
#   background-color: #f3f9fc;
#   color: #000000;
# }
# #T_fe7e7_row7_col4 {
#   background-color: #cddeec;
#   color: #000000;
# }
# #T_fe7e7_row7_col6 {
#   background-color: #c7d9e9;
#   color: #000000;
# }
# </style>
# <table id="T_fe7e7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe7e7_level0_col0" class="col_heading level0 col0" >Person ID</th>
#       <th id="T_fe7e7_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_fe7e7_level0_col2" class="col_heading level0 col2" >Sleep Duration</th>
#       <th id="T_fe7e7_level0_col3" class="col_heading level0 col3" >Quality of Sleep</th>
#       <th id="T_fe7e7_level0_col4" class="col_heading level0 col4" >Physical Activity Level</th>
#       <th id="T_fe7e7_level0_col5" class="col_heading level0 col5" >Stress Level</th>
#       <th id="T_fe7e7_level0_col6" class="col_heading level0 col6" >Heart Rate</th>
#       <th id="T_fe7e7_level0_col7" class="col_heading level0 col7" >Daily Steps</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe7e7_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_fe7e7_row0_col0" class="data row0 col0" >374.000000</td>
#       <td id="T_fe7e7_row0_col1" class="data row0 col1" >374.000000</td>
#       <td id="T_fe7e7_row0_col2" class="data row0 col2" >374.000000</td>
#       <td id="T_fe7e7_row0_col3" class="data row0 col3" >374.000000</td>
#       <td id="T_fe7e7_row0_col4" class="data row0 col4" >374.000000</td>
#       <td id="T_fe7e7_row0_col5" class="data row0 col5" >374.000000</td>
#       <td id="T_fe7e7_row0_col6" class="data row0 col6" >374.000000</td>
#       <td id="T_fe7e7_row0_col7" class="data row0 col7" >374.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fe7e7_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_fe7e7_row1_col0" class="data row1 col0" >187.500000</td>
#       <td id="T_fe7e7_row1_col1" class="data row1 col1" >42.184492</td>
#       <td id="T_fe7e7_row1_col2" class="data row1 col2" >7.132086</td>
#       <td id="T_fe7e7_row1_col3" class="data row1 col3" >7.312834</td>
#       <td id="T_fe7e7_row1_col4" class="data row1 col4" >59.171123</td>
#       <td id="T_fe7e7_row1_col5" class="data row1 col5" >5.385027</td>
#       <td id="T_fe7e7_row1_col6" class="data row1 col6" >70.165775</td>
#       <td id="T_fe7e7_row1_col7" class="data row1 col7" >6816.844920</td>
#     </tr>
#     <tr>
#       <th id="T_fe7e7_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_fe7e7_row2_col0" class="data row2 col0" >108.108742</td>
#       <td id="T_fe7e7_row2_col1" class="data row2 col1" >8.673133</td>
#       <td id="T_fe7e7_row2_col2" class="data row2 col2" >0.795657</td>
#       <td id="T_fe7e7_row2_col3" class="data row2 col3" >1.196956</td>
#       <td id="T_fe7e7_row2_col4" class="data row2 col4" >20.830804</td>
#       <td id="T_fe7e7_row2_col5" class="data row2 col5" >1.774526</td>
#       <td id="T_fe7e7_row2_col6" class="data row2 col6" >4.135676</td>
#       <td id="T_fe7e7_row2_col7" class="data row2 col7" >1617.915679</td>
#     </tr>
#     <tr>
#       <th id="T_fe7e7_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_fe7e7_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_fe7e7_row3_col1" class="data row3 col1" >27.000000</td>
#       <td id="T_fe7e7_row3_col2" class="data row3 col2" >5.800000</td>
#       <td id="T_fe7e7_row3_col3" class="data row3 col3" >4.000000</td>
#       <td id="T_fe7e7_row3_col4" class="data row3 col4" >30.000000</td>
#       <td id="T_fe7e7_row3_col5" class="data row3 col5" >3.000000</td>
#       <td id="T_fe7e7_row3_col6" class="data row3 col6" >65.000000</td>
#       <td id="T_fe7e7_row3_col7" class="data row3 col7" >3000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fe7e7_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_fe7e7_row4_col0" class="data row4 col0" >94.250000</td>
#       <td id="T_fe7e7_row4_col1" class="data row4 col1" >35.250000</td>
#       <td id="T_fe7e7_row4_col2" class="data row4 col2" >6.400000</td>
#       <td id="T_fe7e7_row4_col3" class="data row4 col3" >6.000000</td>
#       <td id="T_fe7e7_row4_col4" class="data row4 col4" >45.000000</td>
#       <td id="T_fe7e7_row4_col5" class="data row4 col5" >4.000000</td>
#       <td id="T_fe7e7_row4_col6" class="data row4 col6" >68.000000</td>
#       <td id="T_fe7e7_row4_col7" class="data row4 col7" >5600.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fe7e7_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_fe7e7_row5_col0" class="data row5 col0" >187.500000</td>
#       <td id="T_fe7e7_row5_col1" class="data row5 col1" >43.000000</td>
#       <td id="T_fe7e7_row5_col2" class="data row5 col2" >7.200000</td>
#       <td id="T_fe7e7_row5_col3" class="data row5 col3" >7.000000</td>
#       <td id="T_fe7e7_row5_col4" class="data row5 col4" >60.000000</td>
#       <td id="T_fe7e7_row5_col5" class="data row5 col5" >5.000000</td>
#       <td id="T_fe7e7_row5_col6" class="data row5 col6" >70.000000</td>
#       <td id="T_fe7e7_row5_col7" class="data row5 col7" >7000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fe7e7_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_fe7e7_row6_col0" class="data row6 col0" >280.750000</td>
#       <td id="T_fe7e7_row6_col1" cl

# %%
#for statistical info including string values
sleep_data.describe(include='O').style.set_properties(**{'background-color': '#4A235A',
                                                      'color': '#E2EEF3'})
# Out:
# <style type="text/css">
# #T_62017_row0_col0, #T_62017_row0_col1, #T_62017_row0_col2, #T_62017_row0_col3, #T_62017_row0_col4, #T_62017_row1_col0, #T_62017_row1_col1, #T_62017_row1_col2, #T_62017_row1_col3, #T_62017_row1_col4, #T_62017_row2_col0, #T_62017_row2_col1, #T_62017_row2_col2, #T_62017_row2_col3, #T_62017_row2_col4, #T_62017_row3_col0, #T_62017_row3_col1, #T_62017_row3_col2, #T_62017_row3_col3, #T_62017_row3_col4 {
#   background-color: #4A235A;
#   color: #E2EEF3;
# }
# </style>
# <table id="T_62017">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_62017_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_62017_level0_col1" class="col_heading level0 col1" >Occupation</th>
#       <th id="T_62017_level0_col2" class="col_heading level0 col2" >BMI Category</th>
#       <th id="T_62017_level0_col3" class="col_heading level0 col3" >Blood Pressure</th>
#       <th id="T_62017_level0_col4" class="col_heading level0 col4" >Sleep Disorder</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_62017_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_62017_row0_col0" class="data row0 col0" >374</td>
#       <td id="T_62017_row0_col1" class="data row0 col1" >374</td>
#       <td id="T_62017_row0_col2" class="data row0 col2" >374</td>
#       <td id="T_62017_row0_col3" class="data row0 col3" >374</td>
#       <td id="T_62017_row0_col4" class="data row0 col4" >374</td>
#     </tr>
#     <tr>
#       <th id="T_62017_level0_row1" class="row_heading level0 row1" >unique</th>
#       <td id="T_62017_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_62017_row1_col1" class="data row1 col1" >11</td>
#       <td id="T_62017_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_62017_row1_col3" class="data row1 col3" >25</td>
#       <td id="T_62017_row1_col4" class="data row1 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_62017_level0_row2" class="row_heading level0 row2" >top</th>
#       <td id="T_62017_row2_col0" class="data row2 col0" >Male</td>
#       <td id="T_62017_row2_col1" class="data row2 col1" >Nurse</td>
#       <td id="T_62017_row2_col2" class="data row2 col2" >Normal</td>
#       <td id="T_62017_row2_col3" class="data row2 col3" >130/85</td>
#       <td id="T_62017_row2_col4" class="data row2 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_62017_level0_row3" class="row_heading level0 row3" >freq</th>
#       <td id="T_62017_row3_col0" class="data row3 col0" >189</td>
#       <td id="T_62017_row3_col1" class="data row3 col1" >73</td>
#       <td id="T_62017_row3_col2" class="data row3 col2" >195</td>
#       <td id="T_62017_row3_col3" class="data row3 col3" >99</td>
#       <td id="T_62017_row3_col4" class="data row3 col4" >219</td>
#     </tr>
#   </tbody>
# </table>

# %%
columns_name=colored(sleep_data.columns, 'magenta',None, attrs=["blink"]) #for show names of columns
print(columns_name)
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %%
#for colored text output ( Text ,Text colors ,Text highlights , Attributes)
number_of_values=colored(sleep_data.nunique(), "magenta",None, attrs=["blink"])
                        
print(number_of_values) #for number of values of columns
# Out:
# Person ID                  374
# Gender                       2
# Age                         31
# Occupation                  11
# Sleep Duration              27
# Quality of Sleep             6
# Physical Activity Level     16
# Stress Level                 6
# BMI Category                 4
# Blood Pressure              25
# Heart Rate                  19
# Daily Steps                 20
# Sleep Disorder               3
# dtype: int64

# %%
plt.style.use('seaborn-white')
sns.pairplot(data=sleep_data.drop('Person ID',axis=1),hue='Sleep Disorder',palette='mako')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
classes=colored(sleep_data['Sleep Disorder'].unique(), "magenta",None, attrs=["blink"])
print('The outputs from the classification are :',classes)
# Out:
# The outputs from the classification are : ['None' 'Sleep Apnea' 'Insomnia']

# %%
sleep_data['Sleep Disorder'].value_counts()
# Out:
# None           219
# Sleep Apnea     78
# Insomnia        77
# Name: Sleep Disorder, dtype: int64

# %%
fig=px.histogram(sleep_data,x='Sleep Disorder', 
                 barmode="group",color='Sleep Disorder',
                 color_discrete_sequence=['white','#4A235A','#C39BD3'],
                 text_auto=True)
 
    
fig.update_layout(title='<b>Distribution of persons have sleep disorder or not</b>..',
                 title_font={'size':25},
                 paper_bgcolor='#EBDEF0',
                 plot_bgcolor='#EBDEF0',
                 showlegend=True)


fig.update_yaxes(showgrid=False)

fig.show()
# Out:
# <div>                            <div id="3ae1f503-cf8f-4df1-b13a-86acb243d8e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ae1f503-cf8f-4df1-b13a-86acb243d8e2")) {                    Plotly.newPlot(                        "3ae1f503-cf8f-4df1-b13a-86acb243d8e2",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Sleep Disorder=%{x}<br>count=%{y}<extra></extra>","legendgroup":"None","marker":{"color":"white","pattern":{"shape":""}},"name":"None","offsetgroup":"None","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Sleep Disorder=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Sleep Apnea","marker":{"color":"#4A235A","pattern":{"shape":""}},"name":"Sleep Apnea","offsetgroup":"Sleep Apnea","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Sleep Disorder=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Insomnia","marker":{"color":"#C39BD3","pattern":{ ...

# %%
Gender=colored(sleep_data['Gender'].unique(), "magenta",None, attrs=["blink"])
print('The values of Sex column are :',Gender)
# Out:
# The values of Sex column are : ['Male' 'Female']

# %%
sleep_data.groupby('Sleep Disorder')['Gender'].value_counts()
# Out:
# Sleep Disorder  Gender
# Insomnia        Male       41
#                 Female     36
# None            Male      137
#                 Female     82
# Sleep Apnea     Female     67
#                 Male       11
# Name: Gender, dtype: int64

# %%
sleep_data.groupby('Sleep Disorder')['Gender'].value_counts().plot.pie(autopct ='%1.1f%%',figsize=(15,7),
                                                                       colors=['#4A235A','pink','#4A235A','pink','#4A235A','pink'])
plt.title('The relationship between (sex) and (Sleep Disorder)')
plt.axis('equal')
plt.show()

# %%
jobs=colored(sleep_data['Occupation'].unique(), "magenta",None, attrs=["blink"])
print('The types of jobs that exist are :',jobs)
# Out:
# The types of jobs that exist are : ['Software Engineer' 'Doctor' 'Sales Representative' 'Teacher' 'Nurse'
#  'Engineer' 'Accountant' 'Scientist' 'Lawyer' 'Salesperson' 'Manager']

# %%
sleep_data.groupby('Sleep Disorder')['Occupation'].value_counts()
# Out:
# Sleep Disorder  Occupation
# Insomnia        Salesperson             29
#                 Teacher                 27
#                 Accountant               7
#                 Engineer                 5
#                 Doctor                   3
#                 Nurse                    3
#                 Lawyer                   2
#                 Software Engineer        1
# None            Doctor                  64
#                 Engineer                57
#                 Lawyer                  42
#                 Accountant              30
#                 Nurse                    9
#                 Teacher                  9
#                 Software Engineer        3
#                 Salesperson              2
#                 Scientist                2
#                 Manager                  1
# Sleep Apnea     Nurse                   61
#                 Doctor                   4
#                 Teacher                  4
#                 Lawyer                   3
#                 Sales Representative     2
#                 Scientist                2
#                 Engineer                 1
#                 Salesperson              1
# Name: Occupation, dtype: int64

# %%
fig=px.treemap(sleep_data,path=[px.Constant('Jobs'),'Sleep Disorder','Occupation'],
               color='Sleep Disorder',
              color_discrete_sequence=['#EBDEF0','#C39BD3','#4A235A'])


fig.update_layout(title='<b>The effect of job on sleep</b>..',
                 title_font={'size':20})


fig.show()
# Out:
# <div>                            <div id="9a2b5c54-bf7d-4984-9cf5-be46eecd4802" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a2b5c54-bf7d-4984-9cf5-be46eecd4802")) {                    Plotly.newPlot(                        "9a2b5c54-bf7d-4984-9cf5-be46eecd4802",                        [{"branchvalues":"total","customdata":[["Insomnia"],["None"],["Sleep Apnea"],["Insomnia"],["None"],["Insomnia"],["Sleep Apnea"],["None"],["Insomnia"],["None"],["Insomnia"],["Sleep Apnea"],["None"],["Sleep Apnea"],["Sleep Apnea"],["None"],["Insomnia"],["None"],["Sleep Apnea"],["None"],["Insomnia"],["Sleep Apnea"],["Insomnia"],["None"],["Sleep Apnea"],["(?)"],["Insomnia"],["None"],["Sleep Apnea"],["None"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<br>Sleep Disorder=%{customdata[0]}<extra></extra>","ids":["Jobs/Insomnia/Engineer","Jobs/None/Engineer","Jobs/Sleep Apnea/Salesperson","Jobs/Insomnia/Accountant","Jobs/None","Jobs/Insomnia","Jobs/Sleep Apnea/Teacher","Jobs/None/Teacher","Jobs/Insomnia/Teacher","Jobs/None/Software Engineer","Jobs/Insomnia/Software Engineer","Jobs/Sleep Apnea/Scientist","Jobs/None/Scientist","Jobs/Sleep Apnea/Sales Representative","Jobs/Sleep Apnea/Nurse","Jobs/None/Nurse","Jobs/Insomnia/Nurse","Jobs/None/Manager","Jobs/Sleep Apnea/Lawyer","Jobs/None/Lawyer","Jobs/Insomnia/Lawyer","Jobs/Sleep Apnea/Engineer","Jobs/Insomnia/Doctor","Jobs/None/Accountant","Jobs/Sleep Apnea","Jobs","Jobs/Insomnia/Salesperson","Jobs/None/Salesperson","Jobs/Sleep Apnea/Doctor","Jobs/None/Doctor"],"labels":["Engineer","Engineer","Salesperson","Accountant","None","Insomnia","Teacher","Teacher","Teacher","Software Engineer","Software Engineer","Scientist","Scientist","Sales Representative","Nurse","Nurse","Nurse","Manager","Lawyer","Lawyer","Lawyer","Engineer","Doctor","Accountant","Sleep Apnea","Jobs","Salesperson","Salesperson","Doctor","Doctor"],"marker":{"colors":["#EBDEF0","#C39BD3","#4A235A","#EBDEF0","#C39BD3","#EBDEF0","#4A235A","#C39BD3","#EBDEF0","#C39BD3","#EBDEF0","#4A235A","#C39BD3","#4A235A","#4A235A","#C39BD3","#EBDEF0","#C39BD3","#4A235A","#C39BD3","#EBDEF0","#4A235A","#EBDEF0","#C39BD3","#4A235A","#EBDEF0","#EBDEF0","#C39BD3","#4A235A","#C39BD3"]},"name":"","parents":["Jobs/Insomnia","Jobs/None","Jobs/Sleep Apnea","Jobs/Insomnia","Jobs","Jobs","Jobs/Sleep Apnea","Jobs/None","Jobs/Insomnia","Jobs/None","Jobs/Insomnia","Jobs/Sleep Apnea","Jobs/None","Jobs/Sleep Apnea","Jobs/Sleep Apnea","Jobs/None","Jobs/Insomnia","Jobs/None","Jobs/Sleep Apnea","Jobs/None","Jobs/Insomnia","Jobs/Sleep Apnea","Jobs/Insomnia","Jobs/None","Jobs","","Jobs/Insomnia","Jobs/None","Jobs/Sleep Apnea","Jobs/None"],"values":[5,57,1,7,219,77,4,9,27,3,1,2,2,2,61,9,3,1,3,42,2,1,3,30,78,374,29,2,4,64],"type":"treemap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0," ...

# %%
sleep_data.pivot_table(index='Quality of Sleep',columns='Sleep Disorder',values='Sleep Duration',aggfunc='mean').style.background_gradient(cmap='BuPu')
# Out:
# <style type="text/css">
# #T_46240_row0_col0, #T_46240_row0_col2, #T_46240_row2_col1 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_46240_row0_col1, #T_46240_row1_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_46240_row1_col0 {
#   background-color: #c0d4e6;
#   color: #000000;
# }
# #T_46240_row1_col2 {
#   background-color: #b4cce2;
#   color: #000000;
# }
# #T_46240_row2_col0 {
#   background-color: #cddeec;
#   color: #000000;
# }
# #T_46240_row2_col2 {
#   background-color: #e1edf5;
#   color: #000000;
# }
# #T_46240_row3_col0 {
#   background-color: #b0c9e1;
#   color: #000000;
# }
# #T_46240_row3_col1 {
#   background-color: #8c69b0;
#   color: #f1f1f1;
# }
# #T_46240_row3_col2 {
#   background-color: #8947a0;
#   color: #f1f1f1;
# }
# #T_46240_row4_col0, #T_46240_row4_col2 {
#   background-color: #8a5aa9;
#   color: #f1f1f1;
# }
# #T_46240_row4_col1 {
#   background-color: #8c7eba;
#   color: #f1f1f1;
# }
# #T_46240_row5_col0, #T_46240_row5_col1, #T_46240_row5_col2 {
#   background-color: #4d004b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_46240">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Sleep Disorder</th>
#       <th id="T_46240_level0_col0" class="col_heading level0 col0" >Insomnia</th>
#       <th id="T_46240_level0_col1" class="col_heading level0 col1" >None</th>
#       <th id="T_46240_level0_col2" class="col_heading level0 col2" >Sleep Apnea</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Quality of Sleep</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46240_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_46240_row0_col0" class="data row0 col0" >5.900000</td>
#       <td id="T_46240_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_46240_row0_col2" class="data row0 col2" >5.850000</td>
#     </tr>
#     <tr>
#       <th id="T_46240_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_46240_row1_col0" class="data row1 col0" >6.500000</td>
#       <td id="T_46240_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_46240_row1_col2" class="data row1 col2" >6.500000</td>
#     </tr>
#     <tr>
#       <th id="T_46240_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_46240_row2_col0" class="data row2 col0" >6.371875</td>
#       <td id="T_46240_row2_col1" class="data row2 col1" >6.117500</td>
#       <td id="T_46240_row2_col2" class="data row2 col2" >6.118182</td>
#     </tr>
#     <tr>
#       <th id="T_46240_level0_row3" class="row_heading level0 row3" >7</th>
#       <td id="T_46240_row3_col0" class="data row3 col0" >6.638235</td>
#       <td id="T_46240_row3_col1" class="data row3 col1" >7.540000</td>
#       <td id="T_46240_row3_col2" class="data row3 col2" >7.500000</td>
#     </tr>
#     <tr>
#       <th id="T_46240_level0_row4" class="row_heading level0 row4" >8</th>
#       <td id="T_46240_row4_col0" class="data row4 col0" >7.520000</td>
#       <td id="T_46240_row4_col1" class="data row4 col1" >7.399010</td>
#       <td id="T_46240_row4_col2" class="data row4 col2" >7.366667</td>
#     </tr>
#     <tr>
#       <th id="T_46240_level0_row5" class="row_heading level0 row5" >9</th>
#       <td id="T_46240_row5_col0" class="data row5 col0" >8.300000</td>
#       <td id="T_46240_row5_col1" class="data row5 col1" >8.365789</td>
#       <td id="T_46240_row5_col2" class="data row5 col2" >8.096875</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig=px.sunburst(sleep_data,path=[px.Constant('Sleep quality'),'Sleep Disorder','Quality of Sleep'],
               color='Sleep Disorder',values='Sleep Duration',
              color_discrete_sequence=['pink','#4A235A','#FFF3FD'],
              hover_data=['Gender'])

fig.update_layout(title='<b>The effect of quality of sleep on sleep </b>..',
                 title_font={'size':25})

fig.show()
# Out:
# <div>                            <div id="1e718209-d47d-47e9-ae47-79381ebd54a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1e718209-d47d-47e9-ae47-79381ebd54a3")) {                    Plotly.newPlot(                        "1e718209-d47d-47e9-ae47-79381ebd54a3",                        [{"branchvalues":"total","customdata":[["(?)","None"],["(?)","Sleep Apnea"],["(?)","Sleep Apnea"],["Male","Insomnia"],["(?)","Sleep Apnea"],["Female","None"],["Female","Insomnia"],["(?)","Sleep Apnea"],["(?)","None"],["(?)","Insomnia"],["(?)","Sleep Apnea"],["(?)","Insomnia"],["(?)","Insomnia"],["(?)","Sleep Apnea"],["(?)","None"],["(?)","(?)"],["(?)","Insomnia"],["(?)","Sleep Apnea"],["(?)","Insomnia"],["(?)","None"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Sleep Duration=%{value}<br>parent=%{parent}<br>id=%{id}<br>Gender=%{customdata[0]}<br>Sleep Disorder=%{customdata[1]}<extra></extra>","ids":["Sleep quality/None/6","Sleep quality/Sleep Apnea/6","Sleep quality/Sleep Apnea","Sleep quality/Insomnia/4","Sleep quality/Sleep Apnea/9","Sleep quality/None/9","Sleep quality/Insomnia/9","Sleep quality/Sleep Apnea/8","Sleep quality/None/8","Sleep quality/Insomnia/8","Sleep quality/Sleep Apnea/7","Sleep quality/Insomnia/7","Sleep quality/Insomnia/5","Sleep quality/Sleep Apnea/4","Sleep quality/None/7","Sleep quality","Sleep quality/Insomnia/6","Sleep quality/Sleep Apnea/5","Sleep quality/Insomnia","Sleep quality/None"],"labels":["6","6","Sleep Apnea","4","9","9","9","8","8","8","7","7","5","4","7","Sleep quality","6","5","Insomnia","None"],"marker":{"colors":["pink","#4A235A","#4A235A","#FFF3FD","#4A235A","pink","#FFF3FD","#4A235A","pink","#FFF3FD","#4A235A","#FFF3FD","#FFF3FD","#4A235A","pink","pink","#FFF3FD","#4A235A","#FFF3FD","pink"]},"name":"","parents":["Sleep quality/None","Sleep quality/Sleep Apnea","Sleep quality","Sleep quality/Insomnia","Sleep quality/Sleep Apnea","Sleep quality/None","Sleep quality/Insomnia","Sleep quality/Sleep Apnea","Sleep quality/None","Sleep quality/Insomnia","Sleep quality/Sleep Apnea","Sleep quality/Insomnia","Sleep quality/Insomnia","Sleep quality/Sleep Apnea","Sleep quality/None","","Sleep quality/Insomnia","Sleep quality/Sleep Apnea","Sleep quality","Sleep quality"],"values":[244.7,201.9,548.5,5.9,259.09999999999997,317.9,8.3,22.1,747.3,37.6,22.5,225.7,26.0,23.4,301.6,2667.4,203.9,19.5,507.4,1611.5],"type":"sunburst"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0," ...

# %%
fig = px.violin(sleep_data, x="Sleep Disorder",y='Physical Activity Level',
                 color='Sleep Disorder',
                 color_discrete_sequence=['white','#4A235A','#C39BD3'],
                 violinmode='overlay')
               
    
fig.update_layout(title='<b>The effect of activities on sleep </b>..',
                 title_font={'size':25},
                 paper_bgcolor='#EBDEF0',
                 plot_bgcolor='#EBDEF0')

fig.update_yaxes(showgrid=False)
fig.show()
# Out:
# <div>                            <div id="b7f15e6b-2c18-46e2-a3fb-f4df014d4caf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7f15e6b-2c18-46e2-a3fb-f4df014d4caf")) {                    Plotly.newPlot(                        "b7f15e6b-2c18-46e2-a3fb-f4df014d4caf",                        [{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Sleep Disorder=%{x}<br>Physical Activity Level=%{y}<extra></extra>","legendgroup":"None","marker":{"color":"white"},"name":"None","offsetgroup":"None","orientation":"v","scalegroup":"True","showlegend":true,"x":["None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None"],"x0":" ","xaxis":"x","y":[42,60,60,75,75,75,30,75,30,30,30,30,75,75,75,75,75,75,75,75,75,75,75,75,30,75,30,30,75,75,75,75,75,75,75,75,75,75,75,75,45,45,30,75,30,30,75,30,30,75,30,30,30,30,30,30,50,50,50,30,30,30,30,30,30,30,30,30,30,40,40,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,42,70,70,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,50,80,80,60,60,60,60,60,60,60,60,60,60,55,55,90,90,70,55,55,90,90,90,90,90,90,90,90,90,90,90,90,90,90,47,75,90,90,90,90,90,90,90,90,90,90,90,90,90,45,45,45,45,55,90,30,90,30,30,30,30,55,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,30,90,90,75,75,75],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Sleep Disorder=%{x}<br>Physical Activity Level=%{y}<extra></extra>","legendgroup":"Sleep Apnea","marker":{"color":"#4A235A"},"name":"Sleep Apnea","offsetgroup":"Sleep Apnea","orientation":"v","scalegroup":"True","showlegend":true,"x":["Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sle ...

# %%
sleep_data.pivot_table(index='Gender',columns='Sleep Disorder',values='Age',aggfunc='median').plot(kind='bar',color={'#FFF3FD','#4A235A','pink'},
                                                                                                   title='Most affected ages in each type of Sleep Disorder',
                                                                                                    label='Age',alpha=.7)


plt.show()

# %%
fig=px.ecdf(sleep_data,x='Age',
            color='Sleep Disorder',
            color_discrete_sequence=['white','#4A235A','#C39BD3'])


fig.update_layout(title='<b>The effect of ages on sleep </b>..',
                 title_font={'size':25},
                 paper_bgcolor='#EBDEF0',
                 plot_bgcolor='#EBDEF0')


fig.update_xaxes(showgrid=False)
fig.update_yaxes(showgrid=False)
fig.show()
# Out:
# <div>                            <div id="81b1ffa5-4138-4407-b405-2c1654b04056" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("81b1ffa5-4138-4407-b405-2c1654b04056")) {                    Plotly.newPlot(                        "81b1ffa5-4138-4407-b405-2c1654b04056",                        [{"hovertemplate":"Sleep Disorder=None<br>Age=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"None","line":{"dash":"solid","shape":"hv"},"marker":{"color":"white","symbol":"circle"},"mode":"lines","name":"None","orientation":"v","showlegend":true,"x":[27,28,28,29,29,29,29,29,29,29,29,29,30,30,30,30,30,30,30,30,30,30,30,31,31,31,31,31,31,31,31,31,31,31,31,31,31,31,31,31,32,32,32,32,32,32,32,32,32,32,32,32,32,32,32,32,32,33,33,33,33,33,33,33,33,33,33,33,33,35,35,35,35,35,35,35,35,35,35,35,36,36,36,36,36,36,36,36,37,37,37,37,37,37,37,37,37,37,37,37,37,37,37,37,37,37,37,37,38,38,38,38,38,38,38,38,38,38,38,38,38,38,38,38,38,38,39,39,39,39,39,39,39,39,39,39,39,39,39,40,40,40,40,41,41,41,41,41,41,41,41,41,41,41,42,42,42,42,42,42,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,44,44,45,45,45,49,50,50,51,51,51,51,51,52,52,52,53,53,53,53,53,53,53,53,53,53,53,53,53,53,53,53,54,54,54,54,54,54,54,56,56,57,59,59],"xaxis":"x","y":[0.0045662100456621,0.0091324200913242,0.0136986301369863,0.0182648401826484,0.0228310502283105,0.0273972602739726,0.0319634703196347,0.0365296803652968,0.0410958904109589,0.045662100456621,0.0502283105022831,0.0547945205479452,0.0593607305936073,0.0639269406392694,0.0684931506849315,0.0730593607305936,0.0776255707762557,0.0821917808219178,0.0867579908675799,0.091324200913242,0.0958904109589041,0.1004566210045662,0.1050228310502283,0.1095890410958904,0.1141552511415525,0.1187214611872146,0.1232876712328767,0.1278538812785388,0.1324200913242009,0.136986301369863,0.1415525114155251,0.1461187214611872,0.1506849315068493,0.1552511415525114,0.1598173515981735,0.1643835616438356,0.1689497716894977,0.1735159817351598,0.1780821917808219,0.182648401826484,0.1872146118721461,0.1917808219178082,0.1963470319634703,0.2009132420091324,0.2054794520547945,0.2100456621004566,0.2146118721461187,0.2191780821917808,0.2237442922374429,0.228310502283105,0.2328767123287671,0.2374429223744292,0.2420091324200913,0.2465753424657534,0.2511415525114155,0.2557077625570776,0.2602739726027397,0.2648401826484018,0.2694063926940639,0.273972602739726,0.2785388127853881,0.2831050228310502,0.2876712328767123,0.2922374429223744,0.2968036529680365,0.3013698630136986,0.3059360730593607,0.3105022831050228,0.3150684931506849,0.319634703196347,0.3242009132420091,0.3287671232876712,0.3333333333333333,0.3378995433789954,0.3424657534246575,0.3470319634703196,0.3515981735159817,0.3561643835616438,0.3607305936073059,0.365296803652968,0.3698630136986301,0.3744292237442922,0.3789954337899543,0.3835616438356164,0.3881278538812785,0.3926940639269406,0.3972602739726027,0.4018264840182648,0.4063926940639269,0.410958904109589,0.4155251141552511,0.4200913242009132,0.4246575342465753,0.4292237442922374,0.4337899543378995,0.4383561643835616,0.4429223744292237,0.4474885844748858,0.4520547945205479,0.45662100456621,0.4611872146118721,0.4657534246575342,0.4703196347031963,0.4748858447488584,0.4794520547945205,0.4840182648401826,0.4885844748858447,0.4931506849315068,0.4977168949771689,0.502283105022831,0.5068493150684932,0.5114155251141552,0.5159817351598174,0.5205479452054794,0.5251141552511416,0.5296803652968036,0.5342465753424658,0.5388127853881278,0.54337899543379,0.547945205479452,0.5525114155251142,0.5570776255707762,0.5616438356164384,0.5662100456621004,0.5707762557077626,0.5753424657534246,0.5799086757990868,0.5844748858447488,0.589041095890411,0.593607305936073,0.5981735159817352,0.6027397260273972,0.6073059360730594,0.6118721461187214,0.6164 ...

# %%
fig=px.histogram(sleep_data,x='Sleep Disorder',y='Sleep Duration',
                 color='Sleep Disorder',color_discrete_sequence=['white','#4A235A','#C39BD3'],
                 text_auto=True)



fig.update_layout(title='<b>The effect of Sleep Duration on Sleep Disorder</b> ..',
                  titlefont={'size': 24,'family': 'Serif'},
                  showlegend=True, 
                  paper_bgcolor='#EBDEF0',
                  plot_bgcolor='#EBDEF0')



fig.update_yaxes(showgrid=False)




fig.show()
# Out:
# <div>                            <div id="fac45151-62ba-4efc-b736-61a3d42c6f62" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fac45151-62ba-4efc-b736-61a3d42c6f62")) {                    Plotly.newPlot(                        "fac45151-62ba-4efc-b736-61a3d42c6f62",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Sleep Disorder=%{x}<br>sum of Sleep Duration=%{y}<extra></extra>","legendgroup":"None","marker":{"color":"white","pattern":{"shape":""}},"name":"None","offsetgroup":"None","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None"],"xaxis":"x","y":[6.1,6.2,6.2,7.8,7.8,7.8,6.1,7.8,6.1,6.0,6.0,6.0,7.6,7.7,7.7,7.7,7.7,7.8,7.9,7.8,7.9,7.9,7.9,7.9,6.1,7.7,6.1,6.1,7.6,7.6,7.6,7.7,7.7,7.7,7.8,7.7,7.8,7.7,7.8,7.7,7.5,7.5,6.0,7.6,6.0,6.0,7.7,6.0,6.0,7.7,6.0,6.0,6.2,6.2,6.2,6.2,7.2,6.2,6.2,6.1,6.1,6.1,6.1,6.0,6.0,6.0,6.0,6.0,6.0,6.7,6.7,7.5,7.2,7.2,7.2,7.3,7.3,7.3,7.3,7.5,7.1,7.2,7.1,7.1,7.1,7.2,7.2,7.2,6.1,7.8,7.8,7.4,7.2,7.4,7.2,7.4,7.2,7.2,7.2,7.2,7.2,7.2,7.2,7.2,7.2,7.2,7.2,7.5,7.3,7.1,7.3,7.3,7.1,7.3,7.3,7.1,7.3,7.3,7.1,7.1,7.1,7.1,7.1,7.1,7.1,7.1,6.9,8.0,8.0,7.2,7.2,7.2,7.2,7.2,7.2,7.2,7.2,7.2,7.2,7.2,7.2,7.9,7.9,7.3,7.1,7.1,7.7,7.7,7.7,7.7,7.7,7.6,7.6,7.6,7.8,7.8,7.8,7.8,7.8,7.8,6.9,7.6,7.7,7.7,7.7,7.7,7.8,7.7,7.8,7.8,7.8,7.8,7.8,7.8,7.8,6.4,6.5,6.6,6.6,6.9,6.2,8.3,6.0,8.5,8.5,8.5,8.5,7.1,8.4,8.4,8.4,8.5,8.5,8.4,8.4,8.5,8.4,8.4,8.5,8.3,8.5,8.3,8.5,8.3,8.5,8.5,8.4,8.4,8.4,8.4,8.4,8.4,8.4,8.5,8.2,8.2,8.1,8.0,8.1],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Sleep Disorder=%{x}<br>sum of Sleep Duration=%{y}<extra></extra>","legendgroup":"Sleep Apnea","marker":{"color":"#4A235A","pattern":{"shape":""}},"name":"Sleep Apnea","offsetgroup":"Sleep Apnea","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apnea","Sleep Apn ...

# %%
fig=px.scatter_3d(sleep_data,x='BMI Category',y='Blood Pressure',z='Heart Rate',
                  color='Sleep Disorder',width=1000,height=900,
                  color_discrete_sequence=['white','#4A235A','#C39BD3'])


fig.update_layout(title='<b>The relationship between (BMI Category , Blood Pressure and Heart Rate) and their effect on  Sleep Disorder</b> ..',
                  titlefont={'size': 20,'family': 'Serif'},
                  showlegend=True)



fig.show()
# Out:
# <div>                            <div id="89644110-cc84-41b9-a841-e78b01ffe8bc" class="plotly-graph-div" style="height:900px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("89644110-cc84-41b9-a841-e78b01ffe8bc")) {                    Plotly.newPlot(                        "89644110-cc84-41b9-a841-e78b01ffe8bc",                        [{"hovertemplate":"Sleep Disorder=None<br>BMI Category=%{x}<br>Blood Pressure=%{y}<br>Heart Rate=%{z}<extra></extra>","legendgroup":"None","marker":{"color":"white","symbol":"circle"},"mode":"markers","name":"None","scene":"scene","showlegend":true,"x":["Overweight","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal Weight","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal Weight","Overweight","Overweight","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Overweight","Overweight","Normal Weight","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal Weight","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Overweight","Normal Weight","Normal Weight","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal Weight","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal Weight","Normal Weight","Normal Weight","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal Weight","Normal Weight","Normal","Normal","Normal Weight","Overweight","Overweight","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal Weight","Overweight","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Overweight","Overweight","Overweight","Overweight","Overweight","Overweight","Normal","Overweight","Normal","Normal","Normal","Normal","Normal Weight","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal Weight","Normal Weight","Overweight","Overweight","Overweight"],"y":["126/83","125/80","125/80","120/80","120/80","120/80","120/80","120/80","120/80","120/80","120/80","120/80","120/80","120/80","120/80","120/80","120/80","120/80","120/80","120/80","120/80","120/80","120/80","117/76","125/80","120/80","125/80","125/80","120/80","120/80","120/80","120/80","120/80","120/80","120/80","120/80","120/80","120/80","120/80","120/80","120/80","120/80","125/80","120/80","125/80","125/80","120/80","125/80","125/80","120/80","125/80","125/80","125/80","125/80","125/80","125/80","118/76","128/85","128/85","125/80","125/80","125/80","125/80","125/80","125/80","125/80","125/80","125/80","125/80","128/84","128/84","120/80","115/75","125/80","125/80","125/80","125/80","125/80","125/80","120/80","115/75","115/75","115/75","115/75","115/75","115/75","115/75","115/75","126/83","120/80","120/80","130/85","115/75","130/85","115/75","130/85","115/75","115/75","115/75","115/75","115/75","115/75","115/75","115/75","115/75","115/75","115/75","120/80","130/85","115/75","130/85","130/85","115/75","130/85","130/85","115/75 ...

# %%
sleep_data.pivot_table(index='Stress Level',columns='Sleep Disorder',aggfunc={'Sleep Disorder':'count'}).style.background_gradient(cmap='BuPu')
# Out:
# <style type="text/css">
# #T_e7811_row0_col0, #T_e7811_row3_col2, #T_e7811_row4_col1 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_e7811_row0_col1 {
#   background-color: #8a56a7;
#   color: #f1f1f1;
# }
# #T_e7811_row0_col2 {
#   background-color: #800f7b;
#   color: #f1f1f1;
# }
# #T_e7811_row1_col0 {
#   background-color: #8c7cb9;
#   color: #f1f1f1;
# }
# #T_e7811_row1_col1, #T_e7811_row3_col1 {
#   background-color: #88449e;
#   color: #f1f1f1;
# }
# #T_e7811_row1_col2 {
#   background-color: #ecf4f9;
#   color: #000000;
# }
# #T_e7811_row2_col0 {
#   background-color: #e0ecf4;
#   color: #000000;
# }
# #T_e7811_row2_col1, #T_e7811_row4_col0, #T_e7811_row5_col2 {
#   background-color: #4d004b;
#   color: #f1f1f1;
# }
# #T_e7811_row2_col2 {
#   background-color: #e6f0f7;
#   color: #000000;
# }
# #T_e7811_row3_col0 {
#   background-color: #f3f9fb;
#   color: #000000;
# }
# #T_e7811_row4_col2 {
#   background-color: #dae7f1;
#   color: #000000;
# }
# #T_e7811_row5_col0 {
#   background-color: #eef6fa;
#   color: #000000;
# }
# #T_e7811_row5_col1 {
#   background-color: #8c82bc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e7811">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7811_level0_col0" class="col_heading level0 col0" colspan="3">Sleep Disorder</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Sleep Disorder</th>
#       <th id="T_e7811_level1_col0" class="col_heading level1 col0" >Insomnia</th>
#       <th id="T_e7811_level1_col1" class="col_heading level1 col1" >None</th>
#       <th id="T_e7811_level1_col2" class="col_heading level1 col2" >Sleep Apnea</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Stress Level</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7811_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_e7811_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_e7811_row0_col1" class="data row0 col1" >40</td>
#       <td id="T_e7811_row0_col2" class="data row0 col2" >30</td>
#     </tr>
#     <tr>
#       <th id="T_e7811_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_e7811_row1_col0" class="data row1 col0" >24</td>
#       <td id="T_e7811_row1_col1" class="data row1 col1" >43</td>
#       <td id="T_e7811_row1_col2" class="data row1 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_e7811_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_e7811_row2_col0" class="data row2 col0" >6</td>
#       <td id="T_e7811_row2_col1" class="data row2 col1" >57</td>
#       <td id="T_e7811_row2_col2" class="data row2 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_e7811_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_e7811_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_e7811_row3_col1" class="data row3 col1" >43</td>
#       <td id="T_e7811_row3_col2" class="data row3 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e7811_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_e7811_row4_col0" class="data row4 col0" >41</td>
#       <td id="T_e7811_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_e7811_row4_col2" class="data row4 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_e7811_level0_row5" class="row_heading level0 row5" >8</th>
#       <td id="T_e7811_row5_col0" class="data row5 col0" >3</td>
#       <td id="T_e7811_row5_col1" class="data row5 col1" >33</td>
#       <td id="T_e7811_row5_col2" class="data row5 col2" >34</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig=px.histogram(sleep_data,x='Sleep Disorder',
                 color='Sleep Disorder',
                 facet_col='Stress Level',
                 barmode='group',
                 color_discrete_sequence=['white','#4A235A','#C39BD3'],
                 opacity=.8)


fig.update_layout(title='<b>The effect of Stress Level on Sleep Disorder</b> ..',title_font={'size':30},
                  paper_bgcolor='#EBDEF0',
                  plot_bgcolor='#EBDEF0')



fig.update_yaxes(showgrid=False)
fig.show()
# Out:
# <div>                            <div id="b45ecf8c-a059-47cb-bb09-5da9f4a364fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b45ecf8c-a059-47cb-bb09-5da9f4a364fe")) {                    Plotly.newPlot(                        "b45ecf8c-a059-47cb-bb09-5da9f4a364fe",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Sleep Disorder=%{x}<br>Stress Level=6<br>count=%{y}<extra></extra>","legendgroup":"None","marker":{"color":"white","opacity":0.8,"pattern":{"shape":""}},"name":"None","offsetgroup":"None","orientation":"v","showlegend":true,"x":["None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Sleep Disorder=%{x}<br>Stress Level=8<br>count=%{y}<extra></extra>","legendgroup":"None","marker":{"color":"white","opacity":0.8,"pattern":{"shape":""}},"name":"None","offsetgroup":"None","orientation":"v","showlegend":false,"x":["None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None"],"xaxis":"x2","yaxis":"y2","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Sleep Disorder=%{x}<br>Stress Level=7<br>count=%{y}<extra></extra>","legendgroup":"None","marker":{"color":"white","opacity":0.8,"pattern":{"shape":""}},"name":"None","offsetgroup":"None","orientation":"v","showlegend":false,"x":["None","None","None"],"xaxis":"x3","yaxis":"y3","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Sleep Disorder=%{x}<br>Stress Level=4<br>count=%{y}<extra></extra>","legendgroup":"None","marker":{"color":"white","opacity":0.8,"pattern":{"shape":""}},"name":"None","offsetgroup":"None","orientation":"v","showlegend":false,"x":["None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None"],"xaxis":"x4","yaxis":"y4","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Sleep Disorder=%{x}<br>Stress Level=3<br>count=%{y}<extra></extra>","legendgroup":"None","marker":{"color":"white","opacity":0.8,"pattern":{"shape":""}},"name":"None","offsetgroup":"None","orientation":"v","showlegend":false,"x":["None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None"],"xaxis":"x5","yaxis":"y5","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Sleep Disorder=%{x}<br>Stress Level=5<br>count=%{y}<extra></extra>","legendgroup":"None","marker":{"color":"white","opacity":0.8,"pattern":{"shape":""}},"name":"None","offsetgroup":"None","orientation":"v","showlegend":false,"x":["None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","No ...

# %%
BMI_Category=colored(sleep_data['BMI Category'].unique(), "magenta",None, attrs=["blink"])
print('The values of BMI Category column are :',BMI_Category)
# Out:
# The values of BMI Category column are : ['Overweight' 'Normal' 'Obese' 'Normal Weight']

# %%
sleep_data.pivot_table(index='BMI Category',columns='Sleep Disorder',aggfunc={'Sleep Disorder':'count'}).style.background_gradient(cmap='BuPu')
# Out:
# <style type="text/css">
# #T_ab4b4_row0_col0 {
#   background-color: #e9f2f7;
#   color: #000000;
# }
# #T_ab4b4_row0_col1, #T_ab4b4_row3_col0, #T_ab4b4_row3_col2 {
#   background-color: #4d004b;
#   color: #f1f1f1;
# }
# #T_ab4b4_row0_col2 {
#   background-color: #eef6fa;
#   color: #000000;
# }
# #T_ab4b4_row1_col0, #T_ab4b4_row1_col1, #T_ab4b4_row1_col2 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_ab4b4_row2_col0 {
#   background-color: #f1f8fb;
#   color: #000000;
# }
# #T_ab4b4_row2_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_ab4b4_row2_col2 {
#   background-color: #ebf4f8;
#   color: #000000;
# }
# #T_ab4b4_row3_col1 {
#   background-color: #f5fafc;
#   color: #000000;
# }
# </style>
# <table id="T_ab4b4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab4b4_level0_col0" class="col_heading level0 col0" colspan="3">Sleep Disorder</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Sleep Disorder</th>
#       <th id="T_ab4b4_level1_col0" class="col_heading level1 col0" >Insomnia</th>
#       <th id="T_ab4b4_level1_col1" class="col_heading level1 col1" >None</th>
#       <th id="T_ab4b4_level1_col2" class="col_heading level1 col2" >Sleep Apnea</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >BMI Category</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab4b4_level0_row0" class="row_heading level0 row0" >Normal</th>
#       <td id="T_ab4b4_row0_col0" class="data row0 col0" >7.000000</td>
#       <td id="T_ab4b4_row0_col1" class="data row0 col1" >183.000000</td>
#       <td id="T_ab4b4_row0_col2" class="data row0 col2" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ab4b4_level0_row1" class="row_heading level0 row1" >Normal Weight</th>
#       <td id="T_ab4b4_row1_col0" class="data row1 col0" >2.000000</td>
#       <td id="T_ab4b4_row1_col1" class="data row1 col1" >17.000000</td>
#       <td id="T_ab4b4_row1_col2" class="data row1 col2" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ab4b4_level0_row2" class="row_heading level0 row2" >Obese</th>
#       <td id="T_ab4b4_row2_col0" class="data row2 col0" >4.000000</td>
#       <td id="T_ab4b4_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_ab4b4_row2_col2" class="data row2 col2" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ab4b4_level0_row3" class="row_heading level0 row3" >Overweight</th>
#       <td id="T_ab4b4_row3_col0" class="data row3 col0" >64.000000</td>
#       <td id="T_ab4b4_row3_col1" class="data row3 col1" >19.000000</td>
#       <td id="T_ab4b4_row3_col2" class="data row3 col2" >65.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
sleep_data.pivot_table(index='BMI Category',columns='Sleep Disorder',aggfunc={'Sleep Disorder':'count'}).plot.pie(autopct ='%1.1f%%',
                                                                                                                  subplots=True,figsize=(20,10),
                                                                                                                  colors=['#C39BD3','#D2B4DE','#EBDEF0','#F4ECF7'])

plt.axis('equal')
plt.show()

# %%
sleep_data.isna().sum()
# Out:
# Person ID                  0
# Gender                     0
# Age                        0
# Occupation                 0
# Sleep Duration             0
# Quality of Sleep           0
# Physical Activity Level    0
# Stress Level               0
# BMI Category               0
# Blood Pressure             0
# Heart Rate                 0
# Daily Steps                0
# Sleep Disorder             0
# dtype: int64

# %%
sns.heatmap(sleep_data.isna(),cmap='BuPu')
# Out:
# <AxesSubplot:>

# %%
sleep_data.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %%
sleep_data['Blood Pressure'].unique()
# Out:
# array(['126/83', '125/80', '140/90', '120/80', '132/87', '130/86',
#        '117/76', '118/76', '128/85', '131/86', '128/84', '115/75',
#        '135/88', '129/84', '130/85', '115/78', '119/77', '121/79',
#        '125/82', '135/90', '122/80', '142/92', '140/95', '139/91',
#        '118/75'], dtype=object)

# %%
sleep_data['Blood Pressure']=sleep_data['Blood Pressure'].apply(lambda x:0 if x in ['120/80','126/83','125/80','128/84','129/84','117/76','118/76','115/75','125/82','122/80'] else 1)
# 0 = normal blood pressure
# 1 = abnormal blood pressure

# %%
sleep_data["Age"]=pd.cut(sleep_data["Age"],2)
sleep_data["Heart Rate"]=pd.cut(sleep_data["Heart Rate"],4)
sleep_data["Daily Steps"]=pd.cut(sleep_data["Daily Steps"],4)
sleep_data["Sleep Duration"]=pd.cut(sleep_data["Sleep Duration"],3)
sleep_data["Physical Activity Level"]=pd.cut(sleep_data["Physical Activity Level"],4)

# %%
from sklearn.preprocessing import LabelEncoder #for converting non-numeric data (String or Boolean) into numbers
LE=LabelEncoder()

categories=['Gender','Age','Occupation','Sleep Duration','Physical Activity Level','BMI Category','Heart Rate','Daily Steps','Sleep Disorder']
for label in categories:
    sleep_data[label]=LE.fit_transform(sleep_data[label])

# %%
sleep_data.drop(['Person ID'], axis=1, inplace=True)

# %%
correlation=sleep_data.corr()
max_6_corr=correlation.nlargest(6,"Sleep Disorder")
sns.heatmap(max_6_corr,annot=True,fmt=".2F",annot_kws={"size":8},linewidths=0.5,cmap='BuPu')
plt.title('Maximum six features affect Sleep Disorder')
plt.show()

# %%
x=sleep_data.iloc[:,:-1]
y=sleep_data.iloc[:,-1]

x_shape=colored(x.shape, "magenta",None, attrs=["blink"])
y_shape=colored(y.shape, "magenta",None, attrs=["blink"])
print('The dimensions of x is : ',x_shape)
print('The dimensions of y is : ',y_shape)
# Out:
# The dimensions of x is :  (374, 11)
# The dimensions of y is :  (374,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=32,shuffle=True)

# %%
x_train_shape=colored(x_train.shape, "magenta",None, attrs=["blink"])
x_test_shape=colored(x_test.shape, "magenta",None, attrs=["blink"])
y_train_shape=colored(y_train.shape, "magenta",None, attrs=["blink"])
y_test_shape=colored(y_test.shape, "magenta",None, attrs=["blink"])

print("x train dimensions :",x_train_shape)
print("x test dimensions: ",x_test_shape)
print("y train dimensions :",y_train_shape)
print("y test dimensions :",y_test_shape)
# Out:
# x train dimensions : (250, 11)
# x test dimensions:  (124, 11)
# y train dimensions : (250,)
# y test dimensions : (124,)

# %%
from sklearn.linear_model import LogisticRegression
LR=LogisticRegression().fit(x_train,y_train)

# %%
LR_training_score=colored(round(LR.score(x_train,y_train)*100,2), "magenta",None, attrs=["blink"])
LR_testing_score=colored(round(LR.score(x_test,y_test)*100,2), "magenta",None, attrs=["blink"])

print(f"LR training score :",LR_training_score)
print("LR testing score :",LR_testing_score)
# Out:
# LR training score : 90.8
# LR testing score : 91.94

# %%
LR_y_pred=LR.predict(x_test)

# %%
pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting xgboost
#   Downloading xgboost-2.0.0-py3-none-win_amd64.whl (99.7 MB)
#      ---------------------------------------- 99.7/99.7 MB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (1.9.1)
# Requirement already satisfied: numpy in c:\users\vikas\appdata\roaming\python\python39\site-packages (from xgboost) (1.23.5)
# Installing collected packages: xgboost
# Successfully installed xgboost-2.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBClassifier
xgb=XGBClassifier().fit(x_train,y_train)

# %%
xgb_training_score=colored(round(xgb.score(x_train,y_train)*100,2), "magenta",None, attrs=["blink"])
xgb_testing_score=colored(round(xgb.score(x_test,y_test)*100,2), "magenta",None, attrs=["blink"])

print("xgb training score :",xgb_training_score)
print("xgb testing score :",xgb_testing_score)
# Out:
# xgb training score : 93.2
# xgb testing score : 91.13

# %%
xgb_y_pred=xgb.predict(x_test)

# %%
pip install catboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting catboost
#   Downloading catboost-1.2.2-cp39-cp39-win_amd64.whl (101.0 MB)
#      -------------------------------------- 101.0/101.0 MB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.24 in c:\programdata\anaconda3\lib\site-packages (from catboost) (1.4.4)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: plotly in c:\programdata\anaconda3\lib\site-packages (from catboost) (5.9.0)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from catboost) (1.9.1)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\vikas\appdata\roaming\python\python39\site-packages (from catboost) (1.23.5)
# Collecting graphviz
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      ---------------------------------------- 47.0/47.0 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from catboost) (3.5.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vikas\appdata\roaming\python\python39\site-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->catboost) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->catboost) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->catboost) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->catboost) (9.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from plotly->catboost) (8.0.1)
# Installing collected packages: graphviz, catboost
# Successfully installed catboost-1.2.2 graphviz-0.20.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from catboost import CatBoostClassifier
CBC=CatBoostClassifier(verbose=False).fit(x_train,y_train)

# %%
CBC_training_score=colored(round(CBC.score(x_train,y_train)*100,2), "magenta",None, attrs=["blink"])
CBC_testing_score=colored(round(CBC.score(x_test,y_test)*100,2), "magenta",None, attrs=["blink"])

print("CBC training score :",CBC_training_score)
print("CBC testing score :",CBC_testing_score)
# Out:
# CBC training score : 93.2
# CBC testing score : 91.13

# %%
CBC_y_pred=CBC.predict(x_test)

# %%
from sklearn.ensemble import GradientBoostingClassifier
GBC = GradientBoostingClassifier().fit(x_train,y_train)

# %%
GBC_training_score=colored(round(GBC.score(x_train,y_train)*100,2), "magenta",None, attrs=["blink"])
GBC_testing_score=colored(round(GBC.score(x_test,y_test)*100,2), "magenta",None, attrs=["blink"])

print("GBC training score :",GBC_training_score)
print("GBC testing score :",GBC_testing_score)
# Out:
# GBC training score : 93.2
# GBC testing score : 91.13

# %%
GBC_y_pred=GBC.predict(x_test)

# %%
from sklearn.svm import SVC
svc = SVC().fit(x_train,y_train)

# %%
svc_training_score=colored(round(svc.score(x_train,y_train)*100,2), "magenta",None, attrs=["blink"])
svc_testing_score=colored(round(svc.score(x_test,y_test)*100,2), "magenta",None, attrs=["blink"])

print("svc training score :",svc_training_score)
print("svc testing score :",svc_testing_score)
# Out:
# svc training score : 88.8
# svc testing score : 87.9

# %%
svc_y_pred=svc.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
models_predictions=[LR_y_pred,xgb_y_pred,CBC_y_pred,GBC_y_pred,svc_y_pred]
model={1:'LR_y_pred',2:'xgb_y_pred',3:'CBC_y_pred',4:'GBC_y_pred',5:'svc_y_pred'}


plt.figure(figsize=(15,7))
for i,y_pred in enumerate(models_predictions,1) :
    
    cm = confusion_matrix(y_pred,y_test)
    
    plt.subplot(2,3,i)
    sns.heatmap(cm,cmap='BuPu',linewidth=3,fmt='',annot=True,
                xticklabels=['(None)','(Sleep_Apnea)','(Insomnia)'],
                yticklabels=['(None)','(Sleep_Apnea)','(Insomnia)'])
    
    
    plt.title(' CM of  '+ model[i])
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.subplots_adjust(hspace=0.5,wspace=0.5)
